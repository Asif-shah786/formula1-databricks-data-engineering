-- %% [markdown]
-- Formula1 Project recieves data as batches, after every new race
-- To make it incremental processing, we'll use btach_id to process only new data
--
-- Our data:
-- results, sprints,  - Changed Data
-- drivers,constructors, circuits, races - Snapshot Data
--
-- snapshot data reflects current state of the source tables, (history + new)
-- changed data contains only data that has been changed
--
-- **Incremental Load - Project Setup**
