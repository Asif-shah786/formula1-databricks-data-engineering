# %% [markdown]
# ### Ingesting Constructor .csv file

# %%
# %run ../00-common/01-environment-config

# %%
# %run ../00-common/02-bronze_helper

# %%
source_file = f"{landing_forlder_path}/constructors.json"
table_name = f"{catalog_name}.{bronze_schema}.constructors"

# %% [markdown]
# ### Adding Ingestion data

# %%
constructors_schema = """
constructorId STRING,
name STRING,
nationality STRING,
url STRING
"""
constructors_df = (
    spark.read.format('json')
    .schema(constructors_schema)
    .option('mode', 'FAILFAST')
    .load(source_file)
    .select("*", "_metadata")
)

# %%
display(constructors_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>constructorId</th><th>name</th><th>nationality</th><th>url</th><th>_metadata</th></tr></thead><tbody><tr><td>adams</td><td>Adams</td><td>american</td><td>http://en.wikipedia.org/wiki/Adams_(constructor)</td><td>List(dbfs:/Volumes/formula1/landing/files/constructors.json, constructors.json, 26369, 0, 26369, 2026-07-25T19:28:17.000Z)</td></tr><tr><td>afm</td><td>AFM</td><td>german</td><td>http://en.wikipedia.org/wiki/Alex_von_Falkenhausen_Motorenbau</td><td>List(dbfs:/Volumes/formula1/landing/files/constructors.json, constructors.json, 26369, 0, 26369, 2026-07-25T19:28:17.000Z)</td></tr><tr><td>ags</td><td>AGS</td><td>french</td><td>http://en.wikipedia.org/wiki/Automobiles_Gonfaronnaises_Sportives</td><td>List(dbfs:/Volumes/formula1/landing/files/constructors.json, constructors.json, 26369, 0, 26369, 2026-07-25T19:28:17.000Z)</td></tr><tr><td>alfa</td><td>Alfa Romeo</td><td>swiss</td><td>http://en.wikipedia.org/wiki/Alfa_Romeo_in_Formula_One</td><td>List(dbfs:/Volumes/formula1/landing/files/constructors.json, constructors.json, 26369, 0, 26369, 2026-07-25T19:28:17.000Z)</td></tr><tr><td>alphatauri</td><td>AlphaTauri</td><td>italian</td><td>http://en.wikipedia.org/wiki/Scuderia_AlphaTauri</td><td>List(dbfs:/Volumes/formula1/landing/files/constructors.json, constructors.json, 26369, 0, 26369, 2026-07-25T19:28:17.000Z)</td></tr><tr><td>alpine</td><td>Alpine F1 Team</td><td>french</td><td>http://en.wikipedia.org/wiki/Alpine_F1_Team</td><td>List(dbfs:/Volumes/formula1/landing/files/constructors.json, constructors.json, 26369, 0, 26369, 2026-07-25T19:28:17.000Z)</td></tr><tr><td>alta</td><td>Alta</td><td>british</td><td>http://en.wikipedia.org/wiki/Alta_auto_racing_team</td><td>List(dbfs:/Volumes/formula1/landing/files/constructors.json, constructors.json, 26369, 0, 26369, 2026-07-25T19:28:17.000Z)</td></tr><tr><td>amon</td><td>Amon</td><td>new zealander</td><td>http://en.wikipedia.org/wiki/Amon_(Formula_One_team)</td><td>List(dbfs:/Volumes/formula1/landing/files/constructors.json, constructors.json, 26369, 0, 26369, 2026-07-25T19:28:17.000Z)</td></tr><tr><td>apollon</td><td>Apollon</td><td>swiss</td><td>http://en.wikipedia.org/wiki/Apollon_(Formula_One)</td><td>List(dbfs:/Volumes/formula1/landing/files/constructors.json, constructors.json, 26369, 0, 26369, 2026-07-25T19:28:17.000Z)</td></tr><tr><td>arrows</td><td>Arrows</td><td>british</td><td>http://en.wikipedia.org/wiki/Arrows_Grand_Prix_International</td><td>List(dbfs:/Volumes/formula1/landing/files/constructors.json, constructors.json, 26369, 0, 26369, 2026-07-25T19:28:17.000Z)</td></tr><tr><td>arzani-volpini</td><td>Arzani-Volpini</td><td>italian</td><td>http://en.wikipedia.org/wiki/Arzani-Volpini</td><td>List(dbfs:/Volumes/formula1/landing/files/constructors.json, constructors.json, 26369, 0, 26369, 2026-07-25T19:28:17.000Z)</td></tr><tr><td>aston_martin</td><td>Aston Martin</td><td>british</td><td>http://en.wikipedia.org/wiki/Aston_Martin_in_Formula_One</td><td>List(dbfs:/Volumes/formula1/landing/files/constructors.json, constructors.json, 26369, 0, 26369, 2026-07-25T19:28:17.000Z)</td></tr><tr><td>ats</td><td>ATS</td><td>italian</td><td>http://en.wikipedia.org/wiki/ATS_(wheels)</td><td>List(dbfs:/Volumes/formula1/landing/files/constructors.json, constructors.json, 26369, 0, 26369, 2026-07-25T19:28:17.000Z)</td></tr><tr><td>audi</td><td>Audi</td><td>german</td><td>null</td><td>List(dbfs:/Volumes/formula1/landing/files/constructors.json, constructors.json, 26369, 0, 26369, 2026-07-25T19:28:17.000Z)</td></tr><tr><td>bar</td><td>BAR</td><td>british</td><td>http://en.wikipedia.org/wiki/British_American_Racing</td><td>List(dbfs:/Volumes/formula1/landing/files/constructors.json, constructors.json, 26369, 0, 26369, 2026-07-25T19:28:17.000Z)</td></tr><tr><td>behra-porsche</td><td>Behra-Porsche</td><td>italian</td><td>http://en.wikipedia.org/wiki/Behra-Porsche</td><td> ...

# %%
constructors_final_df = add_ingestion_metadata(constructors_df)

# %% [markdown]
# ### Creating Delta table

# %%
(constructors_final_df
 .write
 .mode("overwrite")
 .format('delta')
 .saveAsTable(table_name)
)
display(spark.read.table(table_name))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>constructorId</th><th>name</th><th>nationality</th><th>url</th><th>ingestion_timestamp</th><th>source_file</th></tr></thead><tbody><tr><td>adams</td><td>Adams</td><td>american</td><td>http://en.wikipedia.org/wiki/Adams_(constructor)</td><td>2026-07-26T11:37:10.361Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>afm</td><td>AFM</td><td>german</td><td>http://en.wikipedia.org/wiki/Alex_von_Falkenhausen_Motorenbau</td><td>2026-07-26T11:37:10.361Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>ags</td><td>AGS</td><td>french</td><td>http://en.wikipedia.org/wiki/Automobiles_Gonfaronnaises_Sportives</td><td>2026-07-26T11:37:10.361Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>alfa</td><td>Alfa Romeo</td><td>swiss</td><td>http://en.wikipedia.org/wiki/Alfa_Romeo_in_Formula_One</td><td>2026-07-26T11:37:10.361Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>alphatauri</td><td>AlphaTauri</td><td>italian</td><td>http://en.wikipedia.org/wiki/Scuderia_AlphaTauri</td><td>2026-07-26T11:37:10.361Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>alpine</td><td>Alpine F1 Team</td><td>french</td><td>http://en.wikipedia.org/wiki/Alpine_F1_Team</td><td>2026-07-26T11:37:10.361Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>alta</td><td>Alta</td><td>british</td><td>http://en.wikipedia.org/wiki/Alta_auto_racing_team</td><td>2026-07-26T11:37:10.361Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>amon</td><td>Amon</td><td>new zealander</td><td>http://en.wikipedia.org/wiki/Amon_(Formula_One_team)</td><td>2026-07-26T11:37:10.361Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>apollon</td><td>Apollon</td><td>swiss</td><td>http://en.wikipedia.org/wiki/Apollon_(Formula_One)</td><td>2026-07-26T11:37:10.361Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>arrows</td><td>Arrows</td><td>british</td><td>http://en.wikipedia.org/wiki/Arrows_Grand_Prix_International</td><td>2026-07-26T11:37:10.361Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>arzani-volpini</td><td>Arzani-Volpini</td><td>italian</td><td>http://en.wikipedia.org/wiki/Arzani-Volpini</td><td>2026-07-26T11:37:10.361Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>aston_martin</td><td>Aston Martin</td><td>british</td><td>http://en.wikipedia.org/wiki/Aston_Martin_in_Formula_One</td><td>2026-07-26T11:37:10.361Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>ats</td><td>ATS</td><td>italian</td><td>http://en.wikipedia.org/wiki/ATS_(wheels)</td><td>2026-07-26T11:37:10.361Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>audi</td><td>Audi</td><td>german</td><td>null</td><td>2026-07-26T11:37:10.361Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>bar</td><td>BAR</td><td>british</td><td>http://en.wikipedia.org/wiki/British_American_Racing</td><td>2026-07-26T11:37:10.361Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>behra-porsche</td><td>Behra-Porsche</td><td>italian</td><td>http://en.wikipedia.org/wiki/Behra-Porsche</td><td>2026-07-26T11:37:10.361Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>bellasi</td><td>Bellasi</td><td>swiss</td><td>http://en.wikipedia.org/wiki/Bellasi</td><td>2026-07-26T11:37:10.361Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</td></tr><tr><td>benetton</td><td>Benetton</td><td>italian</td><td>http://en.wikipedia.org/wiki/Benetton_Formula</td><td>2026-07-26T11:37:10.361Z</td><td>dbfs:/Volumes/formula1/landing/files/constructors.json</t ...
